# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import os
import random

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"}

# %%
url = "https://www.melon.com/"
browser = webdriver.Chrome() # 창열기
browser.maximize_window() # 최대창 확대
# 1. naver 페이지 열기
browser.get(url)

# %%
elem = browser.find_element(By.XPATH,'//*[@id="gnb_menu"]/ul[1]/li[1]/a')
time.sleep(1)
elem.click()

# %%
# elem.click()  # 클릭
# elem.send_keys('네이버항공권') # 글자입력
# elem.send_keys(Keys.ENTER)   # enter입력

# %%
### html소스를 BeautifulSoup 형태로 변경
soup = BeautifulSoup(browser.page_source,"lxml")
forms = soup.find("form",{"id":"frm"})
tables = forms.find("table")
trs = tables.find_all("tr") # 상단타이틀도 함께 넘어옴.

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"}
##### 100번 반복
for i,tr in enumerate(trs):
    if i==0: continue
    tds = tr.find_all("td")
    # 순위
    rank = tds[1].find("span",{"class":"rank"}).text.strip()
    # 이미지
    img = tds[3].find("img")['src']
    os.makedirs("melon",exist_ok=True) # 폴더가 없을때만 생성됨.
    img_url = requests.get(img,headers=headers)
    with open(f"melon/melon_{i}.jpg","wb") as f:
        f.write(img_url.content)
    # 노래제목,가수    
    song_info1 = tds[5].find_all("span")[0].text.strip()
    song_info2 = tds[5].find_all("span")[1].text.strip()
    # 좋아요 개수
    cnt =  tds[7].find("span",{"class":"cnt"}).text.strip().split('\n')[1].replace(",","")
    cnt = int(cnt)
    print(rank,img,song_info1,song_info2,cnt)
# Out:
# 1 https://cdnimg.melon.co.kr/cm2/album/images/121/60/000/12160000_20251014164646_500.jpg/melon/resize/120/quality/80/optimize Good Goodbye 화사 (HWASA) 72808
# 2 https://cdnimg.melon.co.kr/cm2/album/images/121/63/032/12163032_20251015164500_500.jpg/melon/resize/120/quality/80/optimize 타임캡슐 다비치 43975
# 3 https://cdnimg.melon.co.kr/cm2/album/images/123/92/184/12392184_20251117102938_500.jpg/melon/resize/120/quality/80/optimize ONE MORE TIME ALLDAY PROJECT 40135
# 4 https://cdnimg.melon.co.kr/cm2/album/images/121/49/391/12149391_20251013150421_500.jpg/melon/resize/120/quality/80/optimize Blue Valentine NMIXX 94125
# 5 https://cdnimg.melon.co.kr/cm/album/images/022/19/671/2219671_500.jpg/melon/resize/120/quality/80/optimize 첫 눈 EXO 311592
# 6 https://cdnimg.melon.co.kr/cm2/album/images/118/59/863/11859863_20250620104512_500.jpg/melon/resize/120/quality/80/optimize Golden HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast 187066
# ...

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"}
tds = trs[1].find_all("td")
# 순위
rank = tds[1].find("span",{"class":"rank"}).text.strip()
# 이미지
img = tds[3].find("img")['src']
os.makedirs("melon",exist_ok=True) # 폴더가 없을때만 생성됨.
img_url = requests.get(img,headers=headers)
with open(f"melon_1.jpg","wb") as f:
    f.write(img_url.content)
# 노래제목,가수    
song_info1 = tds[5].find_all("span")[0].text.strip()
song_info2 = tds[5].find_all("span")[1].text.strip()
# 좋아요 개수
cnt =  tds[7].find("span",{"class":"cnt"}).text.strip().split('\n')[1].replace(",","")
cnt = int(cnt)
print(rank,img,song_info1,song_info2,cnt)
# Out:
# 1 https://cdnimg.melon.co.kr/cm2/album/images/121/60/000/12160000_20251014164646_500.jpg/melon/resize/120/quality/80/optimize Good Goodbye 화사 (HWASA) 72808
