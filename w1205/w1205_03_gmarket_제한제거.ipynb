# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import os
import random
from selenium.webdriver.chrome.options import Options

# 상단 Chrome이 자동화된 테스트 소프트웨어에 의해 제어되고 있습니다 제거
options = Options()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument("--disable-blink-features=AutomationControlled")

# %%
browser = webdriver.Chrome(options=options) # 창열기
browser.maximize_window() # 최대창 확대
for i in range(1,6):
    print(url)
    # 1. naver 페이지 열기
    url = f"https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p={i}"
    browser.get(url)
    time.sleep(3)
    soup = BeautifulSoup(browser.page_source,"lxml")
    with open(f"gmarket_{i}.html","w",encoding="utf8") as f:
        f.write(soup.prettify())
# Out:
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p=5
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p=1
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p=2
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p=3
# https://www.gmarket.co.kr/n/search?spm=gmktpc.home.searchtop.dsearchbox.1fbf486ayv2nzP&keyword=tv&p=4
